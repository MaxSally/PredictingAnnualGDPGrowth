# %%
from sklearn.model_selection import train_test_split
from __future__ import print_function
import numpy as np                 # to use numpy arrays
import tensorflow as tf            # to specify and run computation graphs
import tensorflow_datasets as tfds # to load training data
import keras
import pandas as pd
from keras import backend
from tensorflow.keras import Model, initializers, regularizers, constraints
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Reshape, Bidirectional, Dense, Input, Dropout, LeakyReLU, Concatenate, PReLU, Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-3vr6z3m8 because the default path (/home/cse479/rbockmon2/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
inputs = pd.read_csv('input.csv')

keys = []
for it in inputs:
    keys.append(it)
    
distribution = [4, 9, 24, 26, 27, 28] #horrible design

number_of_tests = len(inputs[keys[0]])

# %%
input_short_term = []
input_long_term = []
output = []

for i in range(number_of_tests):
    instance = []
    if pd.isna(inputs[keys[0]][i]):
        continue
    for j in range(distribution[0], distribution[1]):         
        instance.append(float(inputs[keys[j]][i])/100)

    input_short_term.append(instance)
    instance = []
    for j in range(distribution[1], distribution[2]):
        instance.append(float(inputs[keys[j]][i])/100)
    for j in range(distribution[3], distribution[4]):
        instance.append(float(inputs[keys[j]][i])/100)
    input_long_term.append(instance)

    output.append(float(inputs[keys[distribution[5] - 1]][i])/100)

# %%
print(len(input_short_term))
# Out:
# 112

# %% [markdown]
# # Appending both short term and long term variables into training and testing set

# %%
training_input_short_term = []
training_input_long_term = []
training_output = []

testing_input_short_term = []
testing_input_long_term = []
testing_output = []

for i in range(8):
    for j in range(11):
        training_input_short_term.append(input_short_term[j])
        training_input_long_term.append(input_long_term[j])
        training_output.append(output[j])
        
        
    del input_short_term[0:11]
    del input_long_term[0:11]
    del output[0:11]
        #training_input_short_term = np.delete(input_short_term, j)
        
    for k in range(3):
        testing_input_short_term.append(input_short_term[k])
        testing_input_long_term.append(input_long_term[k])
        testing_output.append(output[k])
        
    del input_short_term[0:3]
    del input_long_term[0:3]
    del output[0:3]

# %%
print(len(training_input_short_term))
# Out:
# 88

# %% [markdown]
# # Verification that training and testing data set are correct length

# %%
# Verification 
print(len(training_input_short_term))
print(len(training_input_long_term))
print(len(training_input_long_term))

print(len(testing_input_short_term))
print(len(testing_input_long_term))
print(len(testing_output))
# Out:
# 88
# 88
# 88
# 24
# 24
# 24

# %% [markdown]
# # Creating each specific long term variables training set

# %%
Capital_Investment_train = []
Labor_Force_Participation_train = []
Fixed_Broadband_train = []
RandD_train = []
Property_Rights_train = []
Freedom_From_Corruption_train = []
Fiscal_Freedom_train = []
Business_Freedom_train = []
Labor_Freedom_train = []
Monetary_Freedom_train = []
Trade_Freedom_train = []
Investment_Freedom_train = []
Financial_Freedom_train = []
Economic_Freedom_Overall_train = []
Pop_Above_65_train = []
Savings_As_GDP_train = []


for i in range(len(training_input_long_term)):
    Capital_Investment_train.append(training_input_long_term[i][0])
    Labor_Force_Participation_train.append(training_input_long_term[i][1])
    Fixed_Broadband_train.append(training_input_long_term[i][2])
    RandD_train.append(training_input_long_term[i][3])
    Property_Rights_train.append(training_input_long_term[i][4])
    Freedom_From_Corruption_train.append(training_input_long_term[i][5])
    Fiscal_Freedom_train.append(training_input_long_term[i][6])
    Business_Freedom_train.append(training_input_long_term[i][7])
    Labor_Freedom_train.append(training_input_long_term[i][8])
    Monetary_Freedom_train.append(training_input_long_term[i][9])
    Trade_Freedom_train.append(training_input_long_term[i][10])
    Investment_Freedom_train.append(training_input_long_term[i][11])
    Financial_Freedom_train.append(training_input_long_term[i][12])
    Economic_Freedom_Overall_train.append(training_input_long_term[i][13])
    Pop_Above_65_train.append(training_input_long_term[i][14])
    Savings_As_GDP_train.append(training_input_long_term[i][15])

# %% [markdown]
# # Creating each specific long term variable test set

# %%
Capital_Investment_test = []
Labor_Force_Participation_test  = []
Fixed_Broadband_test  = []
RandD_test  = []
Property_Rights_test  = []
Freedom_From_Corruption_test  = []
Fiscal_Freedom_test  = []
Business_Freedom_test  = []
Labor_Freedom_test  = []
Monetary_Freedom_test  = []
Trade_Freedom_test  = []
Investment_Freedom_test  = []
Financial_Freedom_test  = []
Economic_Freedom_Overall_test  = []
Pop_Above_65_test  = []
Savings_As_GDP_test  = []

    
for i in range(len(testing_input_long_term)):
    Capital_Investment_test.append(testing_input_long_term[i][0])
    Labor_Force_Participation_test.append(testing_input_long_term[i][1])
    Fixed_Broadband_test.append(testing_input_long_term[i][2])
    RandD_test.append(testing_input_long_term[i][3])
    Property_Rights_test.append(testing_input_long_term[i][4])
    Freedom_From_Corruption_test.append(testing_input_long_term[i][5])
    Fiscal_Freedom_test.append(testing_input_long_term[i][6])
    Business_Freedom_test.append(testing_input_long_term[i][7])
    Labor_Freedom_test.append(testing_input_long_term[i][8])
    Monetary_Freedom_test.append(testing_input_long_term[i][9])
    Trade_Freedom_test.append(testing_input_long_term[i][10])
    Investment_Freedom_test.append(testing_input_long_term[i][11])
    Financial_Freedom_test.append(testing_input_long_term[i][12])
    Economic_Freedom_Overall_test.append(testing_input_long_term[i][13])
    Pop_Above_65_test.append(testing_input_long_term[i][14])
    Savings_As_GDP_test.append(testing_input_long_term[i][15])

# %% [markdown]
# # Overall training and testing arrays

# %%
training_input_short_term = np.array(training_input_short_term)
training_input_long_term = np.array(training_input_long_term)
training_output = np.array(training_output)

# %%
testing_input_short_term = np.array(testing_input_short_term)
testing_input_long_term = np.array(testing_input_long_term)
testing_output = np.array(testing_output)

# %% [markdown]
# # Each specific array of long term variables training and test set

# %%
Capital_Investment_train = np.array(Capital_Investment_train)
Capital_Investment_test = np.array(Capital_Investment_test)

Labor_Force_Participation_train = np.array(Labor_Force_Participation_train)
Labor_Force_Participation_test  = np.array(Labor_Force_Participation_test)

Fixed_Broadband_train = np.array(Fixed_Broadband_train)
Fixed_Broadband_test  = np.array(Fixed_Broadband_test)

RandD_train = np.array(RandD_train)
RandD_test  = np.array(RandD_test)

Property_Rights_train = np.array(Property_Rights_train)
Property_Rights_test = np.array(Property_Rights_test)

Freedom_From_Corruption_train = np.array(Freedom_From_Corruption_train)
Freedom_From_Corruption_test  = np.array(Freedom_From_Corruption_test)

Fiscal_Freedom_train = np.array(Fiscal_Freedom_train)
Fiscal_Freedom_test  = np.array(Fiscal_Freedom_test)

Business_Freedom_train = np.array(Business_Freedom_train)
Business_Freedom_test  = np.array(Business_Freedom_test)

Labor_Freedom_train = np.array(Labor_Freedom_train)
Labor_Freedom_test  = np.array(Labor_Freedom_test)

Monetary_Freedom_train = np.array(Monetary_Freedom_train)
Monetary_Freedom_test  = np.array(Monetary_Freedom_test)

Trade_Freedom_train = np.array(Trade_Freedom_train)
Trade_Freedom_test  = np.array(Trade_Freedom_test)

Investment_Freedom_train = np.array(Investment_Freedom_train)
Investment_Freedom_test  = np.array(Investment_Freedom_test)

Financial_Freedom_train = np.array(Financial_Freedom_train)
Financial_Freedom_test  = np.array(Financial_Freedom_test)

Economic_Freedom_Overall_train = np.array(Economic_Freedom_Overall_train)
Economic_Freedom_Overall_test  = np.array(Economic_Freedom_Overall_test)

Pop_Above_65_train = np.array(Pop_Above_65_train)
Pop_Above_65_test  = np.array(Pop_Above_65_test)

Savings_As_GDP_train = np.array(Savings_As_GDP_train)
Savings_As_GDP_test  = np.array(Savings_As_GDP_test)

# %%
trainLV = [Capital_Investment_train, Labor_Force_Participation_train, Fixed_Broadband_train,
          RandD_train, Property_Rights_train, Freedom_From_Corruption_train, Fiscal_Freedom_train, Business_Freedom_train,
          Labor_Freedom_train, Monetary_Freedom_train, Trade_Freedom_train, Investment_Freedom_train, Financial_Freedom_train,
          Economic_Freedom_Overall_train, Pop_Above_65_train, Savings_As_GDP_train]

testLV = [Capital_Investment_test, Labor_Force_Participation_test, Fixed_Broadband_test,
          RandD_test, Property_Rights_test, Freedom_From_Corruption_test, Fiscal_Freedom_test, Business_Freedom_test,
          Labor_Freedom_train, Monetary_Freedom_test, Trade_Freedom_test, Investment_Freedom_test, Financial_Freedom_test,
          Economic_Freedom_Overall_test, Pop_Above_65_train, Savings_As_GDP_test]

# %% [markdown]
# #  Single long term variable model (Accurate to the project plan from milestone 2)

# %%
short_term_input1 = Input(shape=(5,))
short_term_input2 = Input(shape=(5,))
long_term_input1 = Input(shape=(1,))

x1 = Dense(50)(short_term_input1)
x1 = LeakyReLU(0.2)(x1)
x1 = Dropout(0.35)(x1)

x1 = Dense(50)(x1)
x1 = LeakyReLU(0.2)(x1)
x1 = Dropout(0.5)(x1)

x1 = Dense(50)(x1)
x1 = LeakyReLU(0.2)(x1)

con1 = Concatenate(axis=1)([x1, short_term_input2, long_term_input1])
con1 = Dropout(0.35)(con1)

con1 = Dense(56, activation = "relu")(con1)
con1 = Dropout(0.2)(con1)

con1 = Reshape(target_shape = (1, 56))(con1)

con1 = LSTM(100, return_sequences = True)(con1)
con1 = Dropout(0.2)(con1)

con1 = LSTM(100, return_sequences = True)(con1)
con1 = Dropout(0.35)(con1)

con1 = LSTM(200, return_sequences = True)(con1)
con1 = Dropout(0.35)(con1)
con1 = LSTM(100, return_sequences = True)(con1)
con1 = LSTM(1, return_sequences = True)(con1)

x2 = Dense(1, activation = None)(long_term_input1)
x2 = Reshape(target_shape= (1, 1))(x2)
x2 = LSTM(100, return_sequences = True)(x2)
x2 = LSTM(1, return_sequences = True)(x2)

con2 = Concatenate(axis=1)([con1, x2]) 

output = Dense(1, activation = None)(con2)

SingleLongTermmodel = Model(inputs=[short_term_input1, short_term_input2, long_term_input1], outputs=output)
SingleLongTermmodel.summary()
SingleLongTermmodel.compile(optimizer="adam", loss='mae', metrics = [tf.keras.metrics.RootMeanSquaredError()])
clone_weights = SingleLongTermmodel.get_weights()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 50)           300         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 50)           0           dense[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 50)           0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           2550        dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 50)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50)           0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           2550        dropout_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 50)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56)           0           leaky_re_lu_2[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 56)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 56)           3192        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 56)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 56)        0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 1, 100)       62800       reshape[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1, 100)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 1, 100)       80400       dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1, 100)       0           lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 1, 200)       240800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            2           input_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1, 200)       0           lstm_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 1, 100)       120400      dropout_6[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 1, 100)       40800       reshape_1[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 1, 1)         408         lstm_3[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 1, 1)         408         lstm_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2, 1)         0           lstm_4[0][0]
#                                                                  lstm_6[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2, 1)         2           concatenate_1[0][0]
# ==================================================================================================
# Total params: 554,612
# Trainable params: 554,612
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Mean absolute error
# # Setting the long term to be put into a specific model

# %%
# We need to do each country with each long term variable manually to get the randomized complete block design
#  Train  Test
# [0:11] [0:3] - Canada
# [11:22] [3:6] - Greece
# [22:33] [6:9] - Japan
# [33:44] [9:12] - Malaysia
# [44:55] [12:15] - South Africa
# [55:66] [15:18] - Spain
# [66:77] [18:21] - UK
# [77:88] [21:24] - USA

# We need to do each country with each long term variable manually to get the randomized complete block design
## #  Train  Test
# [0:11] [0:3] - Canada
# [11:22] [3:6] - Greece
# [22:33] [6:9] - Japan
# [33:44] [9:12] - Malaysia
# [44:55] [12:15] - South Africa
# [55:66] [15:18] - Spain
# [66:77] [18:21] - UK
# [77:88] [21:24] - USA

# Designated code: Capital Invested = 0
#                  Labor Force = 1
#                  Fixed Broadband = 2
#                  R&D = 3
#                  Property rights = 4
#                  Free from corruption = 5
#                  Fiscal Freedom = 6
#                  Business Freedom = 7
#                  Labor Freedom = 8
#                  Monetary Freedom = 9
#                  Trade Freedom = 10
#                  Investment Freedom = 11
#                  Financial Freedom = 12
#                  Economic Freedom overall = 13
#                  Pop above 65 = 14
#                  Savings as gdp = 15

# Step 1, only the trainLV and testLV designated code will change. 
# This is because we are the training for the same country but with different long term variables to get the RMSE.
# Hence, only the slicing for the long term variable changes. 

# When we finish all long term variables for one country:
# Step 2, change the slicing to a new country and repeat step 1. Reset the designated code back to 0 from 14.

designated_Code = ["Capital Investment", "Labor Force", "Fixed Broadband", "R&D", "Property rights", "Freedom from Corruption",
                  "Fiscal Freedom", "Business Freedom", "Labor Freedom", "Monetary Freedom", "Trade Freedom", "Investment Freedom",
                  "Financial Freedom", "Overall Economic Freedom", "Pop Above 65", "Savings as GDP"]

country = ["Canada", "Greece", "JPN", "Malaysia", "SouthAfrica", "Spain",
            "UK", "USA"]

# %%
# Use this one and change where necessary
# Replace the lists names with relevant countries. So if you are looking at USA, and not JPN,
# Delete JPN and replace with USA_testRMSE
Canada_test_MAE_RMSE = []
Greece_test_MAE_RMSE = []
JPN_test_MAE_RMSE = []
Malaysia_test_MAE_RMSE = []
SouthAfrica_test_MAE_RMSE = []
Spain_test_MAE_RMSE = []
UK_test_MAE_RMSE = []
USA_test_MAE_RMSE = []

short_term_input1 = Input(shape=(5,))
short_term_input2 = Input(shape=(5,))
long_term_input1 = Input(shape=(1,))

x1 = Dense(50)(short_term_input1)
x1 = LeakyReLU(0.2)(x1)
x1 = Dropout(0.35)(x1)

x1 = Dense(50)(x1)
x1 = LeakyReLU(0.2)(x1)
x1 = Dropout(0.5)(x1)

x1 = Dense(50)(x1)
x1 = LeakyReLU(0.2)(x1)

con1 = Concatenate(axis=1)([x1, short_term_input2, long_term_input1])
con1 = Dropout(0.35)(con1)

con1 = Dense(56, activation = "relu")(con1)
con1 = Dropout(0.2)(con1)

con1 = Reshape(target_shape = (1, 56))(con1)

con1 = LSTM(100, return_sequences = True)(con1)
con1 = Dropout(0.2)(con1)

con1 = LSTM(100, return_sequences = True)(con1)
con1 = Dropout(0.35)(con1)

con1 = LSTM(200, return_sequences = True)(con1)
con1 = Dropout(0.35)(con1)
con1 = LSTM(100, return_sequences = True)(con1)
con1 = LSTM(1, return_sequences = True)(con1)

x2 = Dense(1, activation = None)(long_term_input1)
x2 = Reshape(target_shape= (1, 1))(x2)
x2 = LSTM(100, return_sequences = True)(x2)
x2 = LSTM(1, return_sequences = True)(x2)

con2 = Concatenate(axis=1)([con1, x2]) 

output = Dense(1, activation = None)(con2)

SingleLongTermmodel = Model(inputs=[short_term_input1, short_term_input2, long_term_input1], outputs=output)
SingleLongTermmodel.summary()
SingleLongTermmodel.compile(optimizer="adam", loss='mae', metrics = [tf.keras.metrics.RootMeanSquaredError()])
clone_weights = SingleLongTermmodel.get_weights()

# Will print out the test results for MAE and RMSE

# Slicing for Canada
for i in range(16):
    training_input_short_term_slice = training_input_short_term[44:55] # refers to slicing for country training data
    training_input_long_term1 = trainLV[i][44:55]   # The i is the designated code
    training_output_slice = training_output[44:55]
    
    testing_input_short_term_slice = testing_input_short_term[12:15] # 0:3 refers to slicing for country test data
    testing_input_long_term1 = testLV[i][12:15]
    testing_output_slice = training_output[12:15]

    history = SingleLongTermmodel.fit([training_input_short_term_slice, training_input_short_term_slice,     training_input_long_term1], training_output_slice, epochs = 100, batch_size = 1, verbose=0)
    history2 = SingleLongTermmodel.evaluate(x=[testing_input_short_term_slice, testing_input_short_term_slice, testing_input_long_term1], y=testing_output_slice, batch_size=1, verbose=2)
    SouthAfrica_test_MAE_RMSE.append([designated_Code[i], round(history2[0], 4), round(history2[1], 4)]) # Replace with another relevant country
    SingleLongTermmodel.set_weights(clone_weights) # Resets the weights back to beginning
    

# Slicing for Greece
for i in range(16):
    training_input_short_term_slice = training_input_short_term[55:66] # refers to slicing for country training data
    training_input_long_term1 = trainLV[i][55:66]   # The i is the designated code
    training_output_slice = training_output[55:66]
    
    testing_input_short_term_slice = testing_input_short_term[15:18] # 0:3 refers to slicing for country test data
    testing_input_long_term1 = testLV[i][15:18]
    testing_output_slice = training_output[15:18]

    history = SingleLongTermmodel.fit([training_input_short_term_slice, training_input_short_term_slice,     training_input_long_term1], training_output_slice, epochs = 100, batch_size = 1, verbose=0)
    history2 = SingleLongTermmodel.evaluate(x=[testing_input_short_term_slice, testing_input_short_term_slice, testing_input_long_term1], y=testing_output_slice, batch_size=1, verbose=2)
    Spain_test_MAE_RMSE.append([designated_Code[i], round(history2[0], 4), round(history2[1], 4)]) # Replace with another relevant country
    SingleLongTermmodel.set_weights(clone_weights) # Resets the weights back to beginning
    

short_term_input1 = Input(shape=(5,))
short_term_input2 = Input(shape=(5,))
long_term_input1 = Input(shape=(1,))

x1 = Dense(50)(short_term_input1)
x1 = LeakyReLU(0.2)(x1)
x1 = Dropout(0.35)(x1)

x1 = Dense(50)(x1)
x1 = LeakyReLU(0.2)(x1)
x1 = Dropout(0.5)(x1)

x1 = Dense(50)(x1)
x1 = LeakyReLU(0.2)(x1)

con1 = Concatenate(axis=1)([x1, short_term_input2, long_term_input1])
con1 = Dropout(0.35)(con1)

con1 = Dense(56, activation = "relu")(con1)
con1 = Dropout(0.2)(con1)

con1 = Reshape(target_shape = (1, 56))(con1)

con1 = LSTM(100, return_sequences = True)(con1)
con1 = Dropout(0.2)(con1)

con1 = LSTM(100, return_sequences = True)(con1)
con1 = Dropout(0.35)(con1)

con1 = LSTM(200, return_sequences = True)(con1)
con1 = Dropout(0.35)(con1)
con1 = LSTM(100, return_sequences = True)(con1)
con1 = LSTM(1, return_sequences = True)(con1)

x2 = Dense(1, activation = None)(long_term_input1)
x2 = Reshape(target_shape= (1, 1))(x2)
x2 = LSTM(100, return_sequences = True)(x2)
x2 = LSTM(1, return_sequences = True)(x2)

con2 = Concatenate(axis=1)([con1, x2]) 

output = Dense(1, activation = None)(con2)

SingleLongTermmodel = Model(inputs=[short_term_input1, short_term_input2, long_term_input1], outputs=output)
SingleLongTermmodel.summary()
SingleLongTermmodel.compile(optimizer="adam", loss='mae', metrics = [tf.keras.metrics.RootMeanSquaredError()])
clone_weights = SingleLongTermmodel.get_weights()

# Will print out the test results for MAE and RMSE
   

# Slicing for Japan
for i in range(16):
    training_input_short_term_slice = training_input_short_term[66:77] # refers to slicing for country training data
    training_input_long_term1 = trainLV[i][66:77]   # The i is the designated code
    training_output_slice = training_output[66:77]
    
    testing_input_short_term_slice = testing_input_short_term[18:21] # 0:3 refers to slicing for country test data
    testing_input_long_term1 = testLV[i][18:21]
    testing_output_slice = training_output[18:21]

    history = SingleLongTermmodel.fit([training_input_short_term_slice, training_input_short_term_slice,     training_input_long_term1], training_output_slice, epochs = 100, batch_size = 1, verbose=0)
    history2 = SingleLongTermmodel.evaluate(x=[testing_input_short_term_slice, testing_input_short_term_slice, testing_input_long_term1], y=testing_output_slice, batch_size=1, verbose=2)
    UK_test_MAE_RMSE.append([designated_Code[i], round(history2[0], 4), round(history2[1], 4)]) # Replace with another relevant country
    SingleLongTermmodel.set_weights(clone_weights) # Resets the weights back to beginning
    
# Slicing for Malaysia
for i in range(16):
    training_input_short_term_slice = training_input_short_term[77:88] # 0:11 refers to slicing for country training data
    training_input_long_term1 = trainLV[0][77:88]   # The 3 is the designated code
    training_output_slice = training_output[77:88]
    
    testing_input_short_term_slice = testing_input_short_term[21:24] # 0:3 refers to slicing for country test data
    testing_input_long_term1 = testLV[0][21:24]
    testing_output_slice = training_output[21:24]

    history = SingleLongTermmodel.fit([training_input_short_term_slice, training_input_short_term_slice, training_input_long_term1], training_output_slice, epochs = 100, batch_size = 24, verbose=0)
    history2 = SingleLongTermmodel.evaluate(x=[testing_input_short_term_slice, testing_input_short_term_slice, testing_input_long_term1], y=testing_output_slice, batch_size=2, verbose=2)
    USA_test_MAE_RMSE.append([designated_Code[i], round(history2[0], 4), round(history2[1], 4)]) # Replace with another relevant country
    SingleLongTermmodel.set_weights(clone_weights) # Resets the weights back to beginning
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 50)           300         input_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 50)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 50)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 50)           2550        dropout_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 50)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 50)           0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 50)           2550        dropout_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 50)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56)           0           leaky_re_lu_5[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 56)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 56)           3192        dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 56)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 56)        0           dropout_10[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 1, 100)       62800       reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 1, 100)       0           lstm_7[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 1, 100)       80400       dropout_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1, 100)       0           lstm_8[0][0]
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   (None, 1, 200)       240800      dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            2           input_6[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 1, 200)       0           lstm_9[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1)         0           dense_10[0][0]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  (None, 1, 100)       120400      dropout_13[0][0]
# __________________________________________________________________________________________________
# lstm_12 (LSTM)                  (None, 1, 100)       40800       reshape_3[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  (None, 1, 1)         408         lstm_10[0][0]
# __________________________________________________________________________________________________
# lstm_13 (LSTM)                  (None, 1, 1)         408         lstm_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2, 1)         0           lstm_11[0][0]
#                                                                  lstm_13[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2, 1)         2           concatenate_3[0][0]
# ==================================================================================================
# Total params: 554,612
# Trainable params: 554,612
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 3/3 - 0s - loss: 0.0239 - root_mean_squared_error: 0.0269
# 3/3 - 0s - loss: 0.0228 - root_mean_squared_error: 0.0260
# 3/3 - 0s - loss: 0.0215 - root_mean_squared_error: 0.0248
# 3/3 - 0s - loss: nan - root_mean_squared_error: nan
# 3/3 - 0s - loss: 0.0249 - root_mean_squared_error: 0.0279
# 3/3 - 0s - loss: 0.0239 - root_mean_squared_error: 0.0269
# 3/3 - 0s - loss: 0.0213 - root_mean_squared_error: 0.0247
# 3/3 - 0s - loss: 0.0259 - root_mean_squared_error: 0.0287
# 3/3 - 0s - loss: 0.0244 - root_mean_squared_error: 0.0274
# 3/3 - 0s - loss: 0.0230 - root_mean_squared_error: 0.0261
# 3/3 - 0s - loss: 0.0221 - root_mean_squared_error: 0.0254
# 3/3 - 0s - loss: 0.0259 - root_mean_squared_error: 0.0287
# 3/3 - 0s - loss: 0.0233 - root_mean_squared_error: 0.0265
# 3/3 - 0s - loss: 0.0241 - root_mean_squared_error: 0.0271
# 3/3 - 0s - loss: 0.0279 - root_mean_squared_error: 0.0307
# 3/3 - 0s - loss: 0.0225 - root_mean_squared_error: 0.0257
# 3/3 - 0s - loss: 0.0440 - root_mean_squared_error: 0.0514
# 3/3 - 0s - loss: 0.0380 - root_mean_squared_error: 0.0447
# 3/3 - 0s - loss: 0.0370 - root_mean_squared_error: 0.0433
# 3/3 - 0s - loss: 0.0359 - root_mean_squared_error: 0.0425
# 3/3 - 0s - loss: 0.0352 - root_mean_squared_error: 0.0415
# 3/3 - 0s - loss: 0.0354 - root_mean_squared_error: 0.0420
# 3/3 - 0s - loss: 0.0368 - root_mean_squared_error: 0.0430
# 3/3 - 0s - loss: 0.0353 - root_mean_squared_error: 0.0415
# 3/3 - 0s - loss: 0.0371 - root_mean_squared_error: 0.0434
# 3/3 - 0s - loss: 0.0363 - root_mean_squared_error: 0.0425
# 3/3 - 0s - loss: 0.0359 - root_mean_squared_error: 0.0430
# 3/3 - 0s - loss: 0.0396 - root_mean_squared_error: 0.0464
# 3/3 - 0s - loss: 0.0357 - root_mean_squared_error: 0.0419
# 3/3 - 0s - loss: 0.0383 - root_mean_squared_error: 0.0447
# 3/3 - 0s - loss: 0.0374 - root_mean_squared_error: 0.0437
# 3/3 - 0s - loss: 0.0353 - root_mean_squared_error: 0.0415
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 50)           300         input_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 50)           0           dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 50)           0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 50)           2550        dropout_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 50)           0           dense_13[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 50)           0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 50)           2550        dropout_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 50)           0           dense_14[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56)           0           leaky_re_lu_8[0][0]
#                                                                  input_8[0][0]
#                                                                  input_9[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 56)           0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 56)           3192        dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 56)           0           dense_15[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 56)        0           dropout_17[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, 1, 100)       62800       reshape_4[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 1, 100)       0           lstm_14[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, 1, 100)       80400       dropout_18[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 1, 100)       0           lstm_15[0][0]
# __________________________________________________________________________________________________
# lstm_16 (LSTM)                  (None, 1, 200)       240800      dropout_19[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            2           input_9[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 1, 200)       0           lstm_16[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1)         0           dense_16[0][0]
# __________________________________________________________________________________________________
# lstm_17 (LSTM)                  (None, 1, 100)       120400      dropout_20[0][0]
# __________________________________________________________________________________________________
# lstm_19 (LSTM)                  (None, 1, 100)       40800       reshape_5[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 1, 1)         408         lstm_17[0][0]
# __________________________________________________________________________________________________
# lstm_20 (LSTM)                  (None, 1, 1)         408         lstm_19[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 2, 1)         0           lstm_18[0][0]
#                                                                  lstm_20[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 2, 1)         2           concatenate_5[0][0]
# ==================================================================================================
# Total params: 554,612
# Trainable params: 554,612
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 3/3 - 0s - loss: 0.0071 - root_mean_squared_error: 0.0098
# 3/3 - 0s - loss: 0.0086 - root_mean_squared_error: 0.0110
# 3/3 - 0s - loss: 0.0083 - root_mean_squared_error: 0.0107
# 3/3 - 0s - loss: 0.0084 - root_mean_squared_error: 0.0108
# 3/3 - 0s - loss: 0.0101 - root_mean_squared_error: 0.0122
# 3/3 - 0s - loss: 0.0074 - root_mean_squared_error: 0.0100
# 3/3 - 0s - loss: 0.0101 - root_mean_squared_error: 0.0122
# 3/3 - 0s - loss: 0.0097 - root_mean_squared_error: 0.0118
# 3/3 - 0s - loss: 0.0071 - root_mean_squared_error: 0.0098
# 3/3 - 0s - loss: 0.0090 - root_mean_squared_error: 0.0113
# 3/3 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0112
# 3/3 - 0s - loss: 0.0079 - root_mean_squared_error: 0.0105
# 3/3 - 0s - loss: 0.0076 - root_mean_squared_error: 0.0102
# 3/3 - 0s - loss: 0.0089 - root_mean_squared_error: 0.0112
# 3/3 - 0s - loss: 0.0079 - root_mean_squared_error: 0.0104
# 3/3 - 0s - loss: 0.0074 - root_mean_squared_error: 0.0099
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0269
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0269
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0247 - root_mean_squared_error: 0.0267
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0269
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0269
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0269
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0269
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268
# 2/2 - 0s - loss: 0.0248 - root_mean_squared_error: 0.0268

# %%
SouthAfrica_test_MAE_RMSE = np.array(SouthAfrica_test_MAE_RMSE)
Spain_test_MAE_RMSE = np.array(Spain_test_MAE_RMSE)
UK_test_MAE_RMSE = np.array(UK_test_MAE_RMSE)
USA_test_MAE_RMSE = np.array(USA_test_MAE_RMSE)


print("For Canada: ") 
print("Long term Variable  MAE RMSE")
print(SouthAfrica_test_MAE_RMSE)
print("\n")

print("For Greece: ")  
print("Long term Variable  MAE RMSE")
print(Spain_test_MAE_RMSE)
print("\n")

print("For Japan: ") 
print("Long term Variable  MAE RMSE")
print(UK_test_MAE_RMSE)
print("\n")

print("For Malaysia: ") 
print("Country Long term Variable  MAE RMSE")
print(USA_test_MAE_RMSE)
#print(Malaysia_testRMSE)
# Out:
# For Canada:
# Long term Variable  MAE RMSE
# [['Capital Investment' '0.0239' '0.027']
#  ['Labor Force' '0.0245' '0.0274']
#  ['Fixed Broadband' '0.0236' '0.0266']
#  ['R&D' 'nan' 'nan']
#  ['Property rights' '0.0281' '0.031']
#  ['Freedom from Corruption' '0.02' '0.0235']
#  ['Fiscal Freedom' '0.0203' '0.0237']
#  ['Business Freedom' '0.024' '0.0271']
#  ['Labor Freedom' '0.023' '0.0262']
#  ['Monetary Freedom' '0.0246' '0.0276']
#  ['Trade Freedom' '0.0255' '0.0283']
#  ['Investment Freedom' '0.0217' '0.0251']
#  ['Financial Freedom' '0.0215' '0.0251']
#  ['Overall Economic Freedom' '0.0209' '0.0243']
#  ['Pop Above 65' '0.0259' '0.0287']
#  ['Savings as GDP' '0.022' '0.0252']]
#
#
# For Greece:
# Long term Variable  MAE RMSE
# [['Capital Investment' '0.0434' '0.0501']
#  ['Labor Force' '0.0378' '0.0447']
#  ['Fixed Broadband' '0.0368' '0.0424']
#  ['R&D' '0.0369' '0.0436']
#  ['Property rights' '0.0361' '0.0424']
#  ['Freedom from Corruption' '0.0365' '0.0433']
#  ['Fiscal Freedom' '0.0368' '0.0438']
#  ['Business Freedom' '0.038' '0.0445']
#  ['Labor Freedom' '0.036' '0.0423']
#  ['Monetary Freedom' '0.0365' '0.0438']
#  ['Trade Freedom' '0.0366' '0.0429']
#  ['Investment Freedom' '0.0352' '0.0415']
#  ['Financial Freedom' '0.0375' '0.0438']
#  ['Overall Economic Freedom' '0.037' '0.0434']
#  ['Pop Above 65' '0.0398' '0.0467']
#  ['Savings as GDP' '0.0366' '0.0428']]
#
#
# For Japan:
# Long term Variable  MAE RMSE
# [['Capital Investment' '0.0111' '0.013']
#  ['Labor Force' '0.0096' '0.0118']
#  ['Fixed Broadband' '0.009' '0.0113']
#  ['R&D' '0.0095' '0.0117']
#  ['Property rights' '0.0086' '0.0109']
#  ['Freedom from Corruption' '0.0089' '0.0112']
#  ['Fiscal Freedom' '0.0098' '0.0119']
#  ['Business Freedom' '0.0098' '0.012']
#  ['Labor Freedom' '0.008' '0.0106']
#  ['Monetary Freedom' '0.0101' '0.0122']
#  ['Trade Freedom' '0.0075' '0.0101']
#  ['Investment Freedom' '0.0078' '0.0103']
#  ['Financial Freedom' '0.0074' '0.01']
#  ['Overall Economic Freedom' '0.0087' '0.0111']
#  ['Pop Above 65' '0.0088' '0.0111']
#  ['Savings as GDP' '0.0085' '0.0109']]
#
#
# For Malaysia:
# Country Long term Variable  MAE RMSE
# [['Capital Investment' '0.0248' '0.0268']
#  ['Labor Force' '0.0248' '0.0268']
#  ['Fixed Broadband' '0.0248' '0.0269']
#  ['R&D' '0.0248' '0.0269']
#  ['Property rights' '0.0248' '0.0269']
#  ['Freedom from Corruption' '0.0248' '0.0268']
#  ['Fiscal Freedom' '0.0248' '0.0268']
#  ['Business Freedom' '0.0248' '0.0269']
#  ['Labor Freedom' '0.0248' '0.0268']
#  ['Monetary Freedom' '0.0248' '0.0269']
#  ['Trade Freedom' '0.0248' '0.0269']
#  ['Investment Freedom' '0.0248' '0.0268']
#  ['Financial Freedom' '0.0248' '0.0268']
#  ['Overall Economic Freedom' '0.0248' '0.0268']
#  ['Pop Above 65' '0.0248' '0.0268']
#  ['Savings as GDP' '0.0248' '0.0268']]

# %% [markdown]
# # Mean squared error

# %% [raw]
# # Mean squared error (Metrics = Root mean Square error)
#
# SingleLongTermmodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse', metrics = [tf.keras.metrics.RootMeanSquaredError()])
# history = SingleLongTermmodel.fit([training_input_short_term, training_input_short_term, training_input_long_term1], training_output, epochs = 1000, batch_size = 32, verbose = 1)
# history2 = SingleLongTermmodel.evaluate(x=[testing_input_short_term, testing_input_short_term, testing_input_long_term1], y=testing_output, batch_size=32, verbose=1)

# %% [markdown]
# # Multiple long term variable

# %% [raw]
# short_term_input1 = Input(shape=(5,))
# short_term_input2 = Input(shape=(5,))
# long_term_input1 = Input(shape=(1,))
# long_term_input2 = Input(shape=(1, ))
# x3 = Reshape(target_shape = (1, 1))(long_term_input2)
#
# x1 = Dense(50)(short_term_input1)
# x1 = LeakyReLU(0.2)(x1)
# x1 = Dropout(0.35)(x1)
#
# x1 = Dense(50)(x1)
# x1 = LeakyReLU(0.2)(x1)
# x1 = Dropout(0.5)(x1)
#
# x1 = Dense(50)(x1)
# x1 = LeakyReLU(0.2)(x1)
#
#
# con1 = Concatenate(axis=1)([x1, short_term_input2, long_term_input1, long_term_input2])
# con1 = Dropout(0.35)(con1)
#
# con1 = Dense(56, activation = "relu")(con1)
# con1 = Dropout(0.2)(con1)
#
# con1 = Reshape(target_shape = (1, 56))(con1)
#
# con1 = LSTM(100, return_sequences = True)(con1)
# con1 = Dropout(0.2)(con1)
#
# con1 = LSTM(100, return_sequences = True)(con1)
# con1 = Dropout(0.35)(con1)
#
# con1 = LSTM(200, return_sequences = True)(con1)
# con1 = Dropout(0.35)(con1)
# con1 = LSTM(100, return_sequences = True)(con1)
# con1 = LSTM(1, return_sequences = True)(con1)
#
#
# con2 = Concatenate(axis=1)([long_term_input1, long_term_input2])
# x2 = Dense(16, activation = "relu")(con2)
# x2 = Reshape(target_shape= (1, 16))(x2)
# x2 = LSTM(100, return_sequences = True)(x2)
# x2 = LSTM(1, return_sequences = True)(x2)
#
# con2 = Concatenate(axis=1)([con1, x2, x3])
# #con2 = Reshape(target_shape= (3, ))(con2)
# (con2) = Dense(100, activation = 'sigmoid')(con2)
# output = Dense(1, activation = None)(con2)
#
# MultipleInputmodel = Model(inputs=[short_term_input1, short_term_input2, long_term_input1, long_term_input2], outputs=output)
# MultipleInputmodel.summary()
#
# MultipleInputmodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mean_absolute_error', metrics = [tf.keras.metrics.RootMeanSquaredError()])
# #model.compile(optimizer= "adam", loss='mean_absolute_error')

# %% [raw]
# history = MultipleInputmodel.fit([training_input_short_term, training_input_short_term, training_input_long_term1, training_input_long_term2], training_output, epochs = 10000, batch_size = 32, verbose = 1)
# history2 = model.evaluate(x=[testing_input_short_term, testing_input_short_term, testing_input_long_term1, testing_input_long_term2], y=testing_output, batch_size=32, verbose=1)
